# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("Train Average.csv")

# %%
df.head()
# Out:
#     Id          X0          X1          X2          X3          X4  \
# 0  706  760.244080  651.485554  544.015634  436.329441  327.483123
# 1  239  757.366380  648.608429  542.140774  435.783153  327.979855
# 2  613  757.052326  647.617134  539.643149  432.602521  324.675926
# 3  588  760.571769  653.376852  545.164554  436.497520  327.571212
# 4  780  768.801759  658.560595  548.335155  438.108322  327.919567
#
#            X5          X6        X7        X8  ...         X45         X46  \
# 0  217.863934  108.019269  0.937269  0.951192  ...  799.018561  802.089990
# 1  219.361207  110.118326  1.379567  1.327264  ...  843.542838  842.857125
# 2  216.201226  107.946291  0.864291  0.889800  ...  802.832857  806.061425
# 3  217.852478  107.890450  0.808450  0.849468  ...  802.832857  806.061425
# 4  218.198430  107.904851  0.822851  0.859613  ...  769.918551  767.918551
#
#           X47         X48         X49         X50         X51         X52  \
# ...

# %%
df.tail()
# Out:
#       Id          X0          X1          X2          X3          X4  \
# 789  835  766.069784  657.135482  547.388504  437.845491  328.185528
# 790  192  765.594878  655.269284  543.975129  434.702496  325.810317
# 791  629  745.048053  637.129383  532.787281  428.039717  322.276980
# 792  559  749.796813  641.139493  534.113155  427.204250  321.279535
# 793  684  751.815084  643.611521  535.085493  428.639503  322.142241
#
#              X5          X6        X7        X8  ...         X45         X46  \
# 789  218.028639  107.914278  0.832278  0.871526  ...  795.332857  798.318575
# 790  218.644965  107.773425  0.691425  0.753405  ...  836.432841  835.747129
# 791  215.515941  108.017202  0.935202  0.955176  ...  802.832857  806.061425
# 792  215.034990  108.291468  0.045067  0.182486  ...  774.485700  772.114275
# 793  215.273721  107.944552  0.862552  0.900114  ...  799.018561  802.089990
#
#             X47         X48         X49         X50         X51         X52  \
# ...

# %%
df.dtypes
# Out:
# Id       int64
# X0     float64
# X1     float64
# X2     float64
# X3     float64
# X4     float64
# X5     float64
# X6     float64
# X7     float64
# X8     float64
# X9     float64
# X10    float64
# X11    float64
# X12    float64
# X13    float64
# X14    float64
# X15    float64
# X16    float64
# X17    float64
# X18    float64
# X19    float64
# X20    float64
# X21    float64
# X22    float64
# X23    float64
# X24    float64
# X25    float64
# X26    float64
# X27    float64
# X28    float64
# X29    float64
# X30    float64
# X31    float64
# X32    float64
# X33    float64
# X34    float64
# X35    float64
# X36    float64
# X37    float64
# X38    float64
# X39    float64
# X40    float64
# X41    float64
# X42    float64
# X43    float64
# X44    float64
# X45    float64
# X46    float64
# X47    float64
# X48    float64
# X49    float64
# X50    float64
# X51    float64
# X52    float64
# X53    float64
# X54    float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                Id          X0          X1          X2          X3          X4  \
# count  794.000000  794.000000  794.000000  794.000000  794.000000  794.000000
# mean   438.658690  754.278720  646.558147  538.864067  431.182200  323.516851
# std    254.610219   10.442060    8.922687    7.242142    5.661157    4.119253
# min      0.000000  705.253328  605.903860  514.204925  409.235550  305.034993
# 25%    217.250000  747.748846  640.708349  534.027691  427.309234  320.941740
# 50%    438.500000  755.405549  647.681227  539.734078  431.811689  323.973789
# 75%    658.750000  761.893819  653.034166  544.206752  435.278567  326.493082
# max    881.000000  781.188660  669.141474  557.211231  445.340957  333.629819
#
#                X5          X6            X7          X8  ...         X45  \
# count  794.000000  794.000000  7.940000e+02  794.000000  ...  794.000000
# mean   215.868100  108.202595  9.259752e-01    0.943806  ...  808.141079
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 56 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      794 non-null    int64
#  1   X0      794 non-null    float64
#  2   X1      794 non-null    float64
#  3   X2      794 non-null    float64
#  4   X3      794 non-null    float64
#  5   X4      794 non-null    float64
#  6   X5      794 non-null    float64
#  7   X6      794 non-null    float64
#  8   X7      794 non-null    float64
#  9   X8      794 non-null    float64
#  10  X9      794 non-null    float64
#  11  X10     794 non-null    float64
#  12  X11     794 non-null    float64
#  13  X12     794 non-null    float64
#  14  X13     794 non-null    float64
#  15  X14     794 non-null    float64
#  16  X15     794 non-null    float64
#  17  X16     794 non-null    float64
#  18  X17     794 non-null    float64
#  19  X18     794 non-null    float64
# ...

# %%
sb.set_style('darkgrid')
df.plot(kind='line',legend='reverse',title='visulalizing sensors data',figsize=(30,20))
plt.legend(loc='upper right',shadow = True,bbox_to_anchor= (1.35,0.8))
plt.show()

# %%
# Cointegration Test to look for statistically significant relationships b/ variables
from statsmodels.tsa.vector_ar.vecm import coint_johansen
coint_result = coint_johansen(endog = df, det_order = -1, k_ar_diff = 5).eig
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:577: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   warnings.warn("Critical values are only available for time series "
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-9-fb4ead898da0> in <module>
#       1 # Cointegration Test to look for statistically significant relationships b/ variables
#       2 from statsmodels.tsa.vector_ar.vecm import coint_johansen
# ----> 3 coint_result = coint_johansen(endog = df, det_order = -1, k_ar_diff = 5).eig
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py in coint_johansen(endog, det_order, k_ar_diff)
#     626     au, du = np.linalg.eig(np.dot(tmp, sig))  # au is eval, du is evec
#     627
# ...
